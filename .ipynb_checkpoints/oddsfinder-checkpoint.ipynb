# %%
import numpy as np
from numba import njit, prange
from pokerkit import (
    NoLimitTexasHoldem,
    Automation,
    Card
)
from pokerkit.hands import StandardHighHand  # Correct class for hand evaluation
from collections import Counter
import random

COMBINATIONS_7C5 = np.array([
    [0,1,2,3,4], [0,1,2,3,5], [0,1,2,3,6],
    [0,1,2,4,5], [0,1,2,4,6], [0,1,2,5,6],
    [0,1,3,4,5], [0,1,3,4,6], [0,1,3,5,6],
    [0,1,4,5,6], [0,2,3,4,5], [0,2,3,4,6],
    [0,2,3,5,6], [0,2,4,5,6], [0,3,4,5,6],
    [1,2,3,4,5], [1,2,3,4,6], [1,2,3,5,6],
    [1,2,4,5,6], [1,3,4,5,6], [2,3,4,5,6]
], dtype=np.uint8)

def evaluate_hand(player_hand, board):
    """Evaluates a hand using PokerKit's StandardHighHand"""
    # Convert to a single string representation
    hole_cards = "".join(player_hand)  # Example: "AsAc"
    board_cards = "".join(board) if board else ""  # Example: "Kh3sAdAh"
    
    # Use StandardHighHand.from_game with properly formatted strings
    hand = StandardHighHand.from_game(hole_cards, board_cards)
    return hand


def calculate_win_percentage(
    player_hand,
    community_cards=None,
    simulations=100000,
    num_decks=1,
    num_opponents=1
):
    community = list(community_cards) if community_cards else []
    needed_community = 5 - len(community)
    known_cards = Counter(player_hand + community)

    deck = [
        f"{r}{s}"
        for _ in range(num_decks)
        for r in '23456789TJQKA'
        for s in 'shdc'
    ]

    wins = 0
    ties = 0

    for _ in range(simulations):
        temp_deck = list(deck)
        for card in known_cards:
            for _ in range(known_cards[card]):
                if card in temp_deck:
                    temp_deck.remove(card)

        random.shuffle(temp_deck)

        # Generate opponent hands
        opp_hands = []
        for _ in range(num_opponents):
            opp_hand = random.sample(temp_deck, 2)
            opp_hands.append(opp_hand)
            for card in opp_hand:
                temp_deck.remove(card)

        # Create state with the correct number of players
        total_players = num_opponents + 1
        state = NoLimitTexasHoldem.create_state(
            automations=(
                Automation.ANTE_POSTING,
                Automation.BET_COLLECTION,
                Automation.BLIND_OR_STRADDLE_POSTING,
                Automation.HOLE_CARDS_SHOWING_OR_MUCKING,
                Automation.HAND_KILLING,
                Automation.CHIPS_PUSHING,
                Automation.CHIPS_PULLING,
            ),
            raw_starting_stacks=[1000] * total_players,
            player_count=total_players,
            ante_trimming_status=False,
            raw_antes=0,
            raw_blinds_or_straddles=(1, 2),
            min_bet=2
        )

        # Deal player hole cards
        state.deal_hole(tuple(Card.parse(" ".join(player_hand))))

        # Deal opponent hole cards
        for hand in opp_hands:
            state.deal_hole(tuple(Card.parse(" ".join(hand))))

        # Manually complete community cards if needed
        current_community = list(community)
        while len(current_community) < 5:
            current_community.append(temp_deck.pop())

        # Evaluate all hands using PokerKit
        player_eval = evaluate_hand(player_hand, current_community)
        opponent_evals = [evaluate_hand(opp_hand, current_community) for opp_hand in opp_hands]

        # Determine the winner
        all_hands = [player_eval] + opponent_evals
        best_hand = max(all_hands)
        winner_indexes = [i for i, h in enumerate(all_hands) if h == best_hand]

        if 0 in winner_indexes:
            wins += 1 / len(winner_indexes)
        if len(winner_indexes) > 1:
            ties += 1

    return (wins/simulations*100, ties/simulations*100)

def calculate_odds(player_hand, community_cards=None, simulations=100000, num_decks=1, num_opponents=1, use_pokerkit=True):
    if use_pokerkit:
        return calculate_win_percentage(
            player_hand,
            community_cards,
            simulations,
            num_decks,
            num_opponents
        )
    else:
        return (0.0, 0.0)  # Monte Carlo disabled in this version

if __name__ == "__main__":
    win, tie = calculate_odds(
        ['As', 'Ac'],
        ['Qh', 'Jh', 'Th'],
        simulations=10000,
        num_opponents=3,
        use_pokerkit=True
    )
    print(f"Win: {win:.1f}% | Tie: {tie:.1f}%")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 131
#     128         return (0.0, 0.0)  # Monte Carlo disabled in this version
#     130 if __name__ == "__main__":
# --> 131     win, tie = calculate_odds(
#     132         ['As', 'Ac'],
#     133         ['Qh', 'Jh', 'Th'],
#     134         simulations=10000,
#     135         num_opponents=3,
#     136         use_pokerkit=True
#     137     )
#     138     print(f"Win: {win:.1f}% | Tie: {tie:.1f}%")
#
# Cell In[43], line 120, in calculate_odds(player_hand, community_cards, simulations, num_decks, num_opponents, use_pokerkit)
#     118 def calculate_odds(player_hand, community_cards=None, simulations=100000, num_decks=1, num_opponents=1, use_pokerkit=True):
#     119     if use_pokerkit:
# --> 120         return calculate_win_percentage(
#     121             player_hand,
#     122             community_cards,
#     123             simulations,
#     124             num_decks,
#     125             num_opponents
#     126         )
#     127     else:
#     128         return (0.0, 0.0)
#
# Cell In[43], line 103, in calculate_win_percentage(player_hand, community_cards, simulations, num_decks, num_opponents)
#     100     current_community.append(temp_deck.pop())
#     102 # Evaluate all hands using PokerKit
# --> 103 player_eval = evaluate_hand(player_hand, current_community)
#     104 opponent_evals = [evaluate_hand(opp_hand, current_community) for opp_hand in opp_hands]
#     106 # Determine the winner
#
# Cell In[43], line 28, in evaluate_hand(player_hand, board)
#      25 full_hand = [Card.parse(card) for card in (player_hand + board)]
#      27 # Use StandardHighHand's from_game method with Card objects, not strings
# ---> 28 hand = StandardHighHand.from_game(full_hand[:2], full_hand[2:])
#      29 return hand
#
# File /opt/anaconda3/lib/python3.12/site-packages/pokerkit/hands.py:259, in CombinationHand.from_game(cls, hole_cards, board_cards)
#     254 for combination in combinations(
#     255         chain(Card.clean(hole_cards), Card.clean(board_cards)),
#     256         cls.card_count,
#     257 ):
#     258     try:
# --> 259         hand = cls(combination)
#     260     except ValueError:
#     261         pass
#
# File /opt/anaconda3/lib/python3.12/site-packages/pokerkit/hands.py:119, in Hand.__init__(self, cards)
#     116 def __init__(self, cards: CardsLike) -> None:
#     117     self.__cards = Card.clean(cards)
# --> 119     if not self.lookup.has_entry(self.cards):
#     120         raise ValueError(
#     121             (
#     122                 f'The cards {repr(cards)} form an invalid'
#     123                 f' {type(self).__qualname__} hand.'
#     124             ),
#     125         )
#
# File /opt/anaconda3/lib/python3.12/site-packages/pokerkit/lookups.py:197, in Lookup.has_entry(self, cards)
#     181 """Return whether the cards can be looked up.
#     182
#     183 The cards can be looked up if the lookup contains an entry with
#    (...)
#     194          ``False``.
#     195 """
#     196 try:
# --> 197     key = self._get_key(cards)
#     198 except ValueError:
#     199     key = None
#
# File /opt/anaconda3/lib/python3.12/site-packages/pokerkit/lookups.py:248, in Lookup._get_key(self, cards)
#     246 def _get_key(self, cards: CardsLike) -> tuple[int, bool]:
#     247     cards = Card.clean(cards)
# --> 248     hash_ = self.__hash(Card.get_ranks(cards))
#     249     suitedness = Card.are_suited(cards)
#     251     return hash_, suitedness
#
# File /opt/anaconda3/lib/python3.12/site-packages/pokerkit/lookups.py:129, in Lookup.__hash(cls, ranks)
#     127 @classmethod
#     128 def __hash(cls, ranks: Iterable[Rank]) -> int:
# --> 129     return prod(map(cls.__multipliers.__getitem__, ranks))
#
# File /opt/anaconda3/lib/python3.12/site-packages/pokerkit/utilities.py:295, in Card.get_ranks(cls, cards)
#     284 """Return an iterator of the ranks of each card.
#     285
#     286 >>> Card.get_ranks('2sKh')  # doctest: +ELLIPSIS
#    (...)
#     292 :return: The iterator of the ranks of each card.
#     293 """
#     294 for card in cls.clean(cards):
# --> 295     yield card.rank
#
# AttributeError: 'generator' object has no attribute 'rank'
